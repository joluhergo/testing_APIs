# %% [markdown]
# # Lab | Testing APIs

# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
sentim = requests.post("https://sentim-api.herokuapp.com/api/v1/", json={ "text": "She is sad because I'm happy" }, headers={"Accept": "application/json", "Content-Type": "application/json"})
sentim.status_code
# Out:
# 200

# %%
print(sentim.json())
# Out:
# {'result': {'polarity': 0.15, 'type': 'positive'}, 'sentences': [{'sentence': "She is sad because I'm happy", 'sentiment': {'polarity': 0.15, 'type': 'positive'}}]}

# %%
sentimientos = sentim.json()
sentimientos["result"]
# Out:
# {'polarity': 0.15, 'type': 'positive'}

# %% [markdown]
# # Round 2: Fruity Vice

# %%
fruits = requests.get("https://www.fruityvice.com/api/fruit/all")
fruits.status_code
# Out:
# 200

# %%
results = fruits.json()
results
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Fragaria',
#   'name': 'Blueberry',
#   'id': 33,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 5.5,
#    'protein': 0,
#    'fat': 0.4,
#    'calories': 29,
#    'sugar': 5.4}},
#  {'genus': 'Prunus',
#   'name': 'Cherry',
#   'id': 9,
# ...

# %%
data = pd.DataFrame(results)
data.head(10)
# Out:
#       genus       name  id     family         order  \
# 0     Malus      Apple   6   Rosaceae       Rosales
# 1    Prunus    Apricot  35   Rosaceae       Rosales
# 2      Musa     Banana   1   Musaceae  Zingiberales
# 3  Fragaria  Blueberry  33   Rosaceae       Rosales
# 4    Prunus     Cherry   9   Rosaceae          None
# 5     Durio     Durian  60  Malvaceae      Malvales
# 6     Vitis     Grapes  47   Vitaceae       Vitales
# 7   Psidium      Guava  37  Myrtaceae      Myrtales
# 8    Citrus      Lemon  26   Rutaceae    Sapindales
# 9    Citrus       Lime  44   Rutaceae    Sapindales
#
#                                           nutritions
# 0  {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1  {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2  {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 3  {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 4  {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 5  {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# ...

# %%
flattened_data = json_normalize(results)

flattened_data
#worst API ever:
# Out:
# /var/folders/kt/dc2g95nx3wb67vskcbf0v2n40000gn/T/ipykernel_4402/2141200709.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#         genus        name  id         family          order  \
# 0       Malus       Apple   6       Rosaceae        Rosales
# 1      Prunus     Apricot  35       Rosaceae        Rosales
# 2        Musa      Banana   1       Musaceae   Zingiberales
# 3    Fragaria   Blueberry  33       Rosaceae        Rosales
# 4      Prunus      Cherry   9       Rosaceae           None
# 5       Durio      Durian  60      Malvaceae       Malvales
# 6       Vitis      Grapes  47       Vitaceae        Vitales
# 7     Psidium       Guava  37      Myrtaceae       Myrtales
# 8      Citrus       Lemon  26       Rutaceae     Sapindales
# 9      Citrus        Lime  44       Rutaceae     Sapindales
# 10  Mangifera       Mango  27  Anacardiaceae     Sapindales
# ...
